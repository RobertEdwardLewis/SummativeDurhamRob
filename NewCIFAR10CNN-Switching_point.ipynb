# %%
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import random
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import torch
import torch.utils.data
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import random_split
import torch.optim as optim
import torch
import torch.utils.data
from torch.autograd import Variable
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import preprocessing
from torch.optim import Optimizer
import math
import torchvision.transforms as transforms
import torchvision
import os

# %%
def seed_everything(seed_value):
    random.seed(seed_value)
    np.random.seed(seed_value)
    torch.manual_seed(seed_value)
    os.environ['PYTHONHASHSEED'] = str(seed_value)
    
    if torch.cuda.is_available(): 
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

# %% [markdown]
# ###### Custom Optimizer

# %%
class SWATS(Optimizer):
    r"""Implements Adam and SGD mix algorithm.
    """

    def __init__(self,
                 params, tolerance, lr=1e-3, weight_decay=0,
                 betas=(0.9, 0.999), eps=1e-8, amsgrad=False,
                 momentum=0, dampening=0, nesterov=False,
                 adam_w=0.5, sgd_w=0.5):
        if not 0.0 <= lr:
            raise ValueError("Invalid learning rate: {}".format(lr))
        if not 0.0 <= eps:
            raise ValueError("Invalid epsilon value: {}".format(eps))
        if not 0.0 <= betas[0] < 1.0:
            raise ValueError("Invalid beta parameter at index 0: {}".format(betas[0]))
        if not 0.0 <= betas[1] < 1.0:
            raise ValueError("Invalid beta parameter at index 1: {}".format(betas[1]))
        if not 0.0 <= weight_decay:
            raise ValueError("Invalid weight_decay value: {}".format(weight_decay))
        defaults = dict(tolerance = tolerance,eta = eta,
            lr=lr, weight_decay=weight_decay,
            betas=betas, eps=eps, amsgrad=amsgrad,
            momentum=momentum, dampening=dampening, nesterov=nesterov,
            adam_w=adam_w, sgd_w=sgd_w, phase = 'ADAM'
        )
        super(SWATS, self).__init__(params, defaults)

    def __setstate__(self, state):
        super(SWATS, self).__setstate__(state)
        for group in self.param_groups:
            group.setdefault('amsgrad', False)
            group.setdefault('nesterov', False)

    @torch.no_grad()
    def step(self,c,Mix_batch_count, closure=None):
        """Performs a single optimization step.

        Arguments:
            closure (callable, optional): A closure that reevaluates the model
                and returns the loss.
        """
        loss = None
        if closure is not None:
            with torch.enable_grad():
                loss = closure()
        difference = []
        corrected = []
        sca = []
        
        for group in self.param_groups:
            for p in group['params']:
                if p.grad is None:
                    continue
                grad = p.grad

                state = self.state[p]

                
                
                    
                if group['phase'] == 'SGD':
                    #print("The phase is now SGD")
                    d_p_sgd = self.sgd_step(grad, group, p)
                    p.data.add_(-d_p_sgd * group['lr'])
                    #print("SGD OG lr",group['lr'])
                    continue
                    
                #print("The phase is now ADAM")
                d_p_adam, step_size,exp_avg2, bias_correction2, state['diff'] = self.adam_step(grad, group, p)
                    
                w = d_p_adam*step_size*-1
                p.data.add_(w)
                    
                
                #print("len of grad and p =", len(grad.view(-1)), len(w.view(-1)))
                p_view = w.view(-1)
                pg = p_view.dot(grad.view(-1))
                beta1, beta2 = group['betas']

                if pg != 0:
                    # the non-orthognal scaling estimate
                    scaling = p_view.dot(p_view) / -pg
                    exp_avg2.mul_(beta2).add_(scaling, alpha=1 - beta2)

                    # bias corrected exponential average
                    corrected_exp_avg = exp_avg2 / bias_correction2
                    
                    difference.append(corrected_exp_avg.item() - scaling.item())
                    corrected.append(corrected_exp_avg.item())
                    sca.append(scaling.item())
                    
                    state['diff'] = abs(corrected_exp_avg.item() - scaling.item())
                    
                
                    if (state['step'] > 1 and state['diff'] < group['tolerance'] and corrected_exp_avg > 0 ):
                        
                        print("corrected lr  = ",corrected_exp_avg.item())
                        group['lr'] = corrected_exp_avg.item()
                        print("SGD OG lr",group['lr'])
                        
                        group['phase'] = 'SGD'
                        
                        
                

                    
    

        return loss,difference, corrected, sca


    
    def adam_step(self, grad, group, p):
        amsgrad = group['amsgrad']
        state = self.state[p]
        # State initialization
        if len(state) == 0:
            #state['SGD_lr'] = 0.01
            state['diff'] = 10.0
            state['exp_avg2'] = p.new(1).fill_(0)
            state['step'] = 0
            # Exponential moving average of gradient values
            state['exp_avg'] = torch.zeros_like(p, memory_format=torch.preserve_format)
            # Exponential moving average of squared gradient values
            state['exp_avg_sq'] = torch.zeros_like(p, memory_format=torch.preserve_format)
            if amsgrad:
                # Maintains max of all exp. moving avg. of sq. grad. values
                state['max_exp_avg_sq'] = torch.zeros_like(p, memory_format=torch.preserve_format)
        exp_avg, exp_avg_sq = state['exp_avg'], state['exp_avg_sq']
        if amsgrad:
            max_exp_avg_sq = state['max_exp_avg_sq']
        beta1, beta2 = group['betas']
        state['step'] += 1
        bias_correction1 = 1 - beta1 ** state['step']
        bias_correction2 = 1 - beta2 ** state['step']
        if group['weight_decay'] != 0:
            grad = grad.add(p, alpha=group['weight_decay'])
        # Decay the first and second moment running average coefficient
        exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
        exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
        if amsgrad:
            # Maintains the maximum of all 2nd moment running avg. till now
            torch.max(max_exp_avg_sq, exp_avg_sq, out=max_exp_avg_sq)
            # Use the max. for normalizing running avg. of gradient
            denom = (max_exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(group['eps'])
        else:
            denom = (exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(group['eps'])
        step_size = group['lr'] / bias_correction1

        d_p = exp_avg / denom
        return d_p, step_size, state['exp_avg2'], bias_correction2, state['diff']

    def sgd_step(self, grad, group, p):
        d_p = grad
        
        weight_decay = group['weight_decay']
        momentum = group['momentum']
        dampening = group['dampening']
        nesterov = group['nesterov']
        if weight_decay != 0:
            d_p = d_p.add(p, alpha=weight_decay)
        if momentum != 0:
            param_state = self.state[p]
            if 'momentum_buffer' not in param_state:
                buf = param_state['momentum_buffer'] = torch.clone(d_p).detach()
            else:
                buf = param_state['momentum_buffer']
                buf.mul_(momentum).add_(d_p, alpha=1 - dampening)
            if nesterov:
                d_p = d_p.add(buf, alpha=momentum)
            else:
                d_p = buf

        return d_p

# %%
class MY(Optimizer):
    r"""Implements Adam and SGD mix algorithm.
    """

    def __init__(self,
                 params,
                 lr=1e-3, weight_decay=0,
                 betas=(0.9, 0.999), eps=1e-8, amsgrad=False,
                 momentum=0, dampening=0, nesterov=False,SGD_weight = 0.5, Adam_weight = 0.8, opPrint = True):    
        if not 0.0 <= lr:
            raise ValueError("Invalid learning rate: {}".format(lr))
        if not 0.0 <= eps:
            raise ValueError("Invalid epsilon value: {}".format(eps))
        if not 0.0 <= betas[0] < 1.0:
            raise ValueError("Invalid beta parameter at index 0: {}".format(betas[0]))
        if not 0.0 <= betas[1] < 1.0:
            raise ValueError("Invalid beta parameter at index 1: {}".format(betas[1]))
        if not 0.0 <= weight_decay:
            raise ValueError("Invalid weight_decay value: {}".format(weight_decay))
        defaults = dict(
            lr=lr, weight_decay=weight_decay,
            betas=betas, eps=eps, amsgrad=amsgrad,
            momentum=momentum, dampening=dampening, nesterov=nesterov,Adam_weight = Adam_weight, SGD_weight = SGD_weight,
            phase = 'ADAM', SGD_lr = 0.01
        )
        super(MY, self).__init__(params, defaults)

    def __setstate__(self, state):
        super(MY, self).__setstate__(state)
        for group in self.param_groups:
            group.setdefault('amsgrad', False)
            group.setdefault('nesterov', False)

    @torch.no_grad()
    def step(self ,current_epoch, No_epoch, adam_phase, mix_phase, Mix_batch_count,opPrint = True, closure=None):
        """Performs a single optimization step.

        Arguments:
            closure (callable, optional): A closure that reevaluates the model
                and returns the loss.
        """
        
        loss = None
        if closure is not None:
            with torch.enable_grad():
                loss = closure()

        #print("MY")
        #print(Mix_batch_count)
        inc_list = np.linspace(0,1,int((adam_phase*No_epoch + mix_phase*No_epoch)-adam_phase*No_epoch))
        #inc_list = np.logspace(np.log10(0.01), np.log10(1), int((adam_phase*No_epoch + mix_phase*No_epoch)-adam_phase*No_epoch))

        listt = []
        for group in self.param_groups:
            
            if current_epoch <= adam_phase*No_epoch:
                
                group['phase'] = "ADAM"
                if opPrint == True:
                    print("ADAM | Current epoch = ",current_epoch)


            elif adam_phase*No_epoch <= current_epoch <= (adam_phase*No_epoch + mix_phase*No_epoch):

                group['phase'] = 'MIX'
                group['Adam_weight'] = 1-inc_list[Mix_batch_count]
                group['SGD_weight'] = inc_list[Mix_batch_count]
                
                if opPrint == True:
                    print("\nMix batch count = ", Mix_batch_count)
                    print("\nMIX | Current epoch = ",current_epoch)
                    print("MIX | SGD Weight = ",group['SGD_weight'])
                    print("MIX | Adam Weight = ",group['Adam_weight'])

            else:
                group['phase'] = 'SGD'
                if opPrint == True:
                    print("SGD | Current epoch = ",current_epoch)
            
            for p in group['params']:

                if p.grad is None:
                    continue
                    
                grad = p.grad   
                state = self.state[p]

                if group['phase'] == 'SGD':
                    #print("SGD_LR = ", abs(group['SGD_lr']))
                    
                    d_p_sgd = self.sgd_step(grad, group, p)
                    
                    p.add_(d_p_sgd, alpha=-abs(group['SGD_lr']))
                    
                    continue
                
                if group['phase'] == 'ADAM':
                    #print("The phase is now ADAM")
                    d_p_adam, step_size,exp_avg2, bias_correction2, state['diff'] = self.adam_step(grad, group, p)
                    
                    w = d_p_adam*step_size*-1
                    p.data.add_(w)
                    
                    
                if group['phase'] == 'MIX':
                    #print("The phase is now MIX")
                    
                    
                    d_p_adam, step_size, exp_avg2, bias_correction2, state['diff']  = self.adam_step(grad, group, p)
                    
                    w = d_p_adam*step_size*-1

                    d_p_sgd = self.sgd_step(grad, group, p)
                    
                    megred_d_p = group['SGD_weight'] * d_p_sgd + group['Adam_weight'] * d_p_adam
            
                    merged_lr = group['SGD_weight'] * abs(group['SGD_lr']) + group['Adam_weight'] * step_size

                    p.add_(megred_d_p, alpha=-merged_lr)
                            
                
                
                #print("len of grad and p =", len(grad.view(-1)), len(w.view(-1)))
                p_view = w.view(-1)
                pg = p_view.dot(grad.view(-1))
                beta1, beta2 = group['betas']

                if pg != 0:
                    # the non-orthognal scaling estimate
                    scaling = p_view.dot(p_view) / -pg
                    exp_avg2.mul_(beta2).add_(scaling, alpha=1 - beta2)

                    # bias corrected exponential average
                    corrected_exp_avg = exp_avg2 / bias_correction2
                    listt.append(abs(corrected_exp_avg.item()))
                
                
                    if current_epoch == (adam_phase*No_epoch-1):
                        print("The phase is now MIX")
                        group['SGD_lr'] = corrected_exp_avg.item() # worked0.0134
                        print("SGD_LR = ", abs(group['SGD_lr']))
                    
                    
        
        checker = group['phase']
        return loss,checker,listt
        
               
    def check(self, group):
        if group == 'MIX':
            return True


    def adam_step(self, grad, group, p):
        amsgrad = group['amsgrad']
        state = self.state[p]
        # State initialization
        if len(state) == 0:
            #state['SGD_lr'] = 0.01
            state['diff'] = 10.0
            state['exp_avg2'] = p.new(1).fill_(0)
            state['step'] = 0
            # Exponential moving average of gradient values
            state['exp_avg'] = torch.zeros_like(p, memory_format=torch.preserve_format)
            # Exponential moving average of squared gradient values
            state['exp_avg_sq'] = torch.zeros_like(p, memory_format=torch.preserve_format)
            if amsgrad:
                # Maintains max of all exp. moving avg. of sq. grad. values
                state['max_exp_avg_sq'] = torch.zeros_like(p, memory_format=torch.preserve_format)
        exp_avg, exp_avg_sq = state['exp_avg'], state['exp_avg_sq']
        if amsgrad:
            max_exp_avg_sq = state['max_exp_avg_sq']
        beta1, beta2 = group['betas']
        state['step'] += 1
        bias_correction1 = 1 - beta1 ** state['step']
        bias_correction2 = 1 - beta2 ** state['step']
        if group['weight_decay'] != 0:
            grad = grad.add(p, alpha=group['weight_decay'])
        # Decay the first and second moment running average coefficient
        exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
        exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
        if amsgrad:
            # Maintains the maximum of all 2nd moment running avg. till now
            torch.max(max_exp_avg_sq, exp_avg_sq, out=max_exp_avg_sq)
            # Use the max. for normalizing running avg. of gradient
            denom = (max_exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(group['eps'])
        else:
            denom = (exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(group['eps'])
        step_size = group['lr'] / bias_correction1

        d_p = exp_avg / denom
        return d_p, step_size, state['exp_avg2'], bias_correction2, state['diff']

    def sgd_step(self, grad, group, p):
        d_p = grad
        weight_decay = group['weight_decay']
        momentum = group['momentum']
        dampening = group['dampening']
        nesterov = group['nesterov']
        if weight_decay != 0:
            d_p = d_p.add(p, alpha=weight_decay)
        if momentum != 0:
            param_state = self.state[p]
            if 'momentum_buffer' not in param_state:
                buf = param_state['momentum_buffer'] = torch.clone(d_p).detach()
            else:
                buf = param_state['momentum_buffer']
                buf.mul_(momentum).add_(d_p, alpha=1 - dampening)
            if nesterov:
                d_p = d_p.add(buf, alpha=momentum)
            else:
                d_p = buf

        return d_p

# %% [markdown]
# ### Data Prep

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
transform_train = transforms.Compose([transforms.Resize((32,32)),  #resises the image so it can be perfect for our model.
                                      transforms.RandomHorizontalFlip(), # FLips the image w.r.t horizontal axis
                                      transforms.RandomRotation(10),     #Rotates the image to a specified angel
                                      transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)), #Performs actions like zooms, change shear angles.
                                      transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2), # Set the color params
                                      transforms.ToTensor(), # comvert the image to tensor so that it can work with torch
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)) #Normalize all the images
                               ])
 
 
transform = transforms.Compose([transforms.Resize((32,32)),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                               ])
train = datasets.CIFAR10(root='./data', train=True, download=False, transform=transform_train) # Data augmentation is only done on training images
test = datasets.CIFAR10(root='./data', train=False, download=False, transform=transform)

# %% [markdown]
# #### Our Models

# %%
class LeNet(nn.Module):
    def __init__(self):
      super().__init__()
      self.conv1 = nn.Conv2d(3, 16, 3, 1, padding=1) # input is color image, hence 3 i/p channels. 16 filters, kernal size is tuned to 3 to avoid overfitting, stride is 1 , padding is 1 extract all edge features.
      self.conv2 = nn.Conv2d(16, 32, 3, 1, padding=1) # We double the feature maps for every conv layer as in pratice it is really good.
      self.conv3 = nn.Conv2d(32, 64, 3, 1, padding=1)
      self.fc1 = nn.Linear(4*4*64, 500) # I/p image size is 32*32, after 3 MaxPooling layers it reduces to 4*4 and 64 because our last conv layer has 64 outputs. Output nodes is 500
      self.dropout1 = nn.Dropout(0.5)
      self.fc2 = nn.Linear(500, 10) # output nodes are 10 because our dataset have 10 different categories
    def forward(self, x):
      x = F.relu(self.conv1(x)) #Apply relu to each output of conv layer.
      x = F.max_pool2d(x, 2, 2) # Max pooling layer with kernal of 2 and stride of 2
      x = F.relu(self.conv2(x))
      x = F.max_pool2d(x, 2, 2)
      x = F.relu(self.conv3(x))
      x = F.max_pool2d(x, 2, 2)
      x = x.view(-1, 4*4*64) # flatten our images to 1D to input it to the fully connected layers
      x = F.relu(self.fc1(x))
      x = self.dropout1(x) # Applying dropout b/t layers which exchange highest parameters. This is a good practice
      x = self.fc2(x)
      return x

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %% [markdown]
# #### Trainer

# %%
def TrainVal(model, traindata , testdata, opti ,
           batch_size, loss_fn, epochs , clipping, 
           lr,  weight_decay,
                       
           mom, dampening, nest,
                       
           betas, eps,tolerance, eta, amsgra,
                       
           adam_w, sgd_w,
        
           final_lr,
             
           adam_phase, mix_phase,
                       
           plots = False, Print = False, opPrint = False):
    

    #splitting training data into train and validation set
    test_abs = int(len(traindata) * 0.8)
    train_subset, val_subset = random_split(traindata, [test_abs, len(traindata) - test_abs])
    
    #Loading data into torch loader
    train_loader = torch.utils.data.DataLoader(train_subset, batch_size = batch_size, shuffle = True)
    val_loader = torch.utils.data.DataLoader(val_subset, batch_size = batch_size, shuffle = True)
    
    #Runs model on correct device
    model = model.to(device)
    
    criterion = loss_fn
    
    if opti == "ADAM":
        optimizer = optim.Adam(model.parameters(), lr=lr,betas=betas, eps=eps, amsgrad= amsgra,
                               weight_decay=weight_decay)
    elif opti == "SGD":
        optimizer = optim.SGD(model.parameters(),lr=lr, momentum = mom,dampening = dampening,
                              weight_decay=weight_decay,nesterov=nest )
    elif opti == "ADABOUND":
        optimizer =  AdaBound(model.parameters(), lr=lr, betas=betas, final_lr = final_lr, gamma=1e-3,
                 eps=eps, weight_decay=weight_decay, amsbound=False)
    elif opti == "MY":
        optimizer = MY(model.parameters(),
                 lr=lr, weight_decay=weight_decay,
                 betas=betas, eps=eps, amsgrad=amsgra,momentum=mom, dampening=dampening,
                       nesterov=nest,SGD_weight = 0.0, Adam_weight = 0.5,opPrint =  opPrint)
        
    elif opti == 'SWATS' :
        optimizer = SWATS( model.parameters(),tolerance, lr=lr,
                 betas=betas, eps=eps, amsgrad=amsgra,
                 momentum=mom, dampening=dampening, nesterov=nest,
                 adam_w=adam_w, sgd_w=sgd_w)
        
    elif opti == 'NewSwats':
        optimizer = NewSwats(model.parameters(),tolerance, eta, lr=lr,
                 betas=betas, eps=eps, amsgrad=amsgra,
                 momentum=mom, dampening=dampening, nesterov=nest,
                 adam_w=adam_w, sgd_w=sgd_w)
    else:
        optimizer = AdamSGD(model.parameters(), lr=lr,
                 betas=betas, eps=eps, amsgrad=amsgra,
                 momentum=mom, dampening=dampening, nesterov=nest,
                 adam_w=adam_w, sgd_w=sgd_w)
        
        
    #Some metrics
    epoch_list = []
    
    train_loss_list = []
    train_acc_list = []
    val_loss_list = []
    val_acc_list = []
    batchy_norm = []
    epoch_norm = []
    switch = []
    Mix_batch_count = 0
    diff = []
    corr = []
    sc = []
    listtt = []
    for e in range(epochs): # training our model, put input according to every batch.
        #Train metrics
        train_loss = 0.0
        train_correct = 0
        train_total = 0

        
        #Entering Training mode
        model.train()
        
        #Gradient Norm Metric
        batch_norm = []
        
        for inputs, labels in train_loader:
            
            inputs = inputs.to(device) 
            labels = labels.to(device)
            
            #Outputs of model
            outputs = model(inputs) 
            #Loss of outputs
            loss = criterion(outputs, labels)

            optimizer.zero_grad() 
            
            #gradient step
            loss.backward() 
            
           

            #Grad norm cals
            param_normm = []
            tot = 0
            for p in model.parameters():
                tt = torch.flatten(p.grad).numpy()
                param_normm = np.concatenate((param_normm,tt))

            batch_norm.append(np.sqrt(np.sum(np.power(param_normm,2))))
            batchy_norm.append(np.sqrt(np.sum(np.power(param_normm,2))))
            
            yyy = 0
            if  opti == "SWATS":
                
                losso, difference, corrected, sca= optimizer.step(e+1,18)
                
                diff.append(difference)
                corr.append(corrected)
                sc.append(sca)
                    
                    
            elif opti == 'MY':
                    
                loss0,group,listt = optimizer.step(e+1, epochs,adam_phase, mix_phase, Mix_batch_count)
                listtt.append(listt)
                
            else:
                optimizer.step()

            #Predictions
            _, predicted = torch.max(outputs, 1)
            train_total += labels.size(0)
            train_correct += (predicted == labels).sum().item()
            
            #Loss
            train_loss += loss.item()
        
        if opti == 'MY':
            
            if group == 'MIX':
                Mix_batch_count += 1
                
        epoch_list.append(e+1)
        

        epoch_norm.append(np.mean(batch_norm))
        train_loss_list.append(train_loss/train_total)
        train_acc_list.append(100*train_correct/train_total)
        if Print == True:
            print('Epoch: {} \tTrain Loss: {:.4f}\t Acc: {:.2f}%'.format(e+1, train_loss/train_total, 100*train_correct/(train_total)) )
        
              
        #Validation
        # Calculate Accuracy 
        model.eval() 
  

        
        #Val metrics
        val_loss = 0.0
        val_correct = 0.0
        val_total = 0.0
        
        with torch.no_grad(): # we do not need gradient for validation.
            for val_inputs, val_labels in val_loader:
                
                val_inputs = val_inputs.to(device)
                val_labels = val_labels.to(device)
                
                val_outputs = model(val_inputs)
                
                val_loss = criterion(val_outputs, val_labels)

                #Predictions
                _, predicted = torch.max(val_outputs, 1)
                val_total += val_labels.size(0)
                val_correct += (predicted == val_labels).sum().item()
                
                val_loss += val_loss.item()
 

        val_loss = np.asarray(val_loss/val_total)

        val_loss_list.append(val_loss)

        
        val_acc_list.append(100*val_correct/ val_total)
        
        if Print == True:
            print('Epoch: {} \tVal Loss: {:.4f}\t Acc: {:.2f}%'.format(e+1, val_loss/val_total, 100*val_correct/ val_total ))
        
        
    if plots == True:
        
        plt.plot(epoch_list,epoch_norm)
        plt.xlabel("Epochs")
        plt.ylabel("Grad Norm")
        plt.title("Grad Norm vs Number of Epochs")
        plt.show()


        plt.plot(epoch_list,train_loss_list)
        plt.xlabel("Epochs")
        plt.ylabel("Loss")
        plt.title("Training Loss vs Number of Epochs")
        plt.show()

        plt.plot(epoch_list,train_acc_list)
        plt.xlabel("Epochs")
        plt.ylabel("Accuracy")
        plt.title("Training acc vs Number of Epochs")
        plt.show()

            
        plt.plot(epoch_list,val_loss_list)
        plt.xlabel("Epochs")
        plt.ylabel("Loss")
        plt.title("val loss vs Number of Epochs")
        plt.show()

        plt.plot(epoch_list,val_acc_list)
        plt.xlabel("Epochs")
        plt.ylabel("Accuracy")
        plt.title("val Accuracy vs Number of Epochs")
        plt.show()
        

    return epoch_list, train_loss_list,train_acc_list, val_loss_list, val_acc_list, batchy_norm, epoch_norm,diff, corr, sc,listtt

# %%
def testing(model, testdata ,
           batch_size, loss_fn ,
         plots = False, Print = False):   
    
    ##Testing
    test_correct = 0
    test_total = 0
    test_loss = 0
    
    
    model.eval() # Required for Evaluation/Test

    y_pred_list = []
    y_actual = []



    test_loader = torch.utils.data.DataLoader(test, batch_size =batch_size, shuffle = True)

    with torch.no_grad():
        for test_inputs, test_labels in test_loader:

            # Convert our images and labels to Variables to accumulate Gradients
            test_inputs = test_inputs.to(device)
            test_labels = test_labels.to(device)
            # Predict Output
            output = model(test_inputs)

            # Calculate Loss
            loss = loss_fn(output, test_labels)
            
            test_loss += loss.item()
            
            # Get predictions from the maximum value

            #Predictions
            _, predicted = torch.max(output, 1)
            test_total += test_labels.size(0)
            test_correct += (predicted == test_labels).sum().item()

            y_pred_list += predicted
            y_actual += test_labels



        # calculate average test loss and accuracy over an epoch
        test_loss = test_loss/test_total
        accuracy_test =  100 * test_correct/ test_total
        
    if Print == True:
        print("test Accuracy = ",accuracy_test)
        print("test loss = ",test_loss)
        
    y_pred_list = [a.squeeze().tolist() for a in y_pred_list]
    return accuracy_test, y_pred_list, y_actual

# %% [markdown]
# ### Hyperparameters

# %%
MY_c = 'green'
SGD_c = 'dodgerblue'
ADAM_c = 'red'
SWATS_c = 'black'

# %%
import time

opti = 'MY'
batch_size = 1024 # set at 1024 after tuning
loss_fn = nn.CrossEntropyLoss()

clipping = False # set to false
lr =  0.001
hidden_dim = 32
drop = 0.2
weight_decay = 0.0
mom = 0.95
dampening = 0
nest = False #set
Betas = (0.9,0.999) # set
eps = 1e-8 # set
amsgra = False #set
adam_w = 0.5
sgd_w= 0.5
tolerance = 0.01 # with 1e-3 switches at 7
eta = 0.0003
final_lr = 0.001
adam_phasee = 0.2
mix_phasee = 0.5  #0.4 works




plots = False
Print = True
opPrint = False
i=0

epochs = 10


seed_everything(1234)


model=LeNet()

epoch_list, train_loss_list,train_acc_list, val_loss_list, val_acc_list, batchy_norm, epoch_norm,diff,corr, sc,listtt = TrainVal(
model, train , test, opti ,batch_size, loss_fn, epochs , clipping, lr,  weight_decay,mom, dampening, nest,(0.9,0.999),
eps,tolerance,eta, amsgra,adam_w,
1-adam_w, final_lr,adam_phase=adam_phasee, mix_phase=mix_phasee,
plots = plots, Print = Print, opPrint = opPrint)

accuracy_test, y_pred_list, y_actual = testing(model, test ,32, loss_fn ,plots = True, Print = True)


tot = 0
j = 1
for p in range(5):
    tot +=val_acc_list[-j]
    j +=1

Validation_Acc_result = tot/5

print("Validation_Acc_result = ",Validation_Acc_result)




fig = plt.figure(figsize=(14,10))
ax = fig.add_subplot()
ax.plot(epoch_list, np.asarray(val_loss_list)*100, label = "MAWS", c = MY_c)
ax.set_xlabel('Epochs', fontsize = 25)
ax.set_ylabel('Testing Loss', fontsize = 25)
ax.tick_params(axis='both', which='major', labelsize=23)
ax.tick_params(axis='both', which='minor', labelsize=23)
ax.legend(fontsize = 25)

fig = plt.figure(figsize=(14,10))
ax2 = fig.add_subplot()
#ax2.set_ylim(40, 83)
#print(val_acc_list)
ax2.plot(epoch_list, val_acc_list, label = "MAWS", c = MY_c)
ax2.set_xlabel('Epochs', fontsize = 25)
ax2.set_ylabel('Testing Accuracy', fontsize = 25)
ax2.tick_params(axis='both', which='major', labelsize=23)
ax2.tick_params(axis='both', which='minor', labelsize=23)
ax2.legend(fontsize = 25)

fig = plt.figure(figsize=(14,10))
ax3 = fig.add_subplot()
ax3.plot(epoch_list, epoch_norm, label = "MAWS", c = MY_c)
ax3.set_xlabel('Epochs', fontsize = 25)
ax3.set_ylabel('Gradient Norm', fontsize = 25)
ax3.tick_params(axis='both', which='major', labelsize=23)
ax3.tick_params(axis='both', which='minor', labelsize=23)
ax3.legend(fontsize = 25)
#############################################################################################################
#ADAM

opti = 'ADAM'
lr = 0.0007


seed_everything(1234)
#Note h,d are not being used
model=LeNet()

epoch_list, train_loss_list,train_acc_list, val_loss_list, val_acc_list, batchy_norm, epoch_norm,diff,corr, sc,listttt = TrainVal(
model, train , test, opti ,batch_size, loss_fn, epochs , clipping, lr,  weight_decay,mom, dampening, nest,(0.9,0.999),
eps,tolerance,eta, amsgra,adam_w,
1-adam_w, final_lr,adam_phase=adam_phasee, mix_phase=mix_phasee,
plots = plots, Print = Print, opPrint = opPrint)

accuracy_test, y_pred_list, y_actual = testing(model, test ,32, loss_fn ,plots = True, Print = True)


tot = 0
j = 1
for p in range(5):
    tot +=val_acc_list[-j]
    j +=1

Validation_Acc_result = tot/5

print("Validation_Acc_result = ",Validation_Acc_result)



ax.plot(epoch_list, np.asarray(val_loss_list)*100, label = "SGD", c =ADAM_c)
ax.set_xlabel('Epochs', fontsize = 25)
ax.set_ylabel('Testing Loss', fontsize = 25)
ax.tick_params(axis='both', which='major', labelsize=23)
ax.tick_params(axis='both', which='minor', labelsize=23)
ax.legend(fontsize = 25)


ax2.plot(epoch_list, val_acc_list, label = "SGD", c =ADAM_c)
ax2.set_xlabel('Epochs', fontsize = 25)
ax2.set_ylabel('Testing Accuracy', fontsize = 25)
ax2.tick_params(axis='both', which='major', labelsize=23)
ax2.tick_params(axis='both', which='minor', labelsize=23)
ax2.legend(fontsize = 25)


ax3.plot(epoch_list, epoch_norm, label = "SGD", c =ADAM_c)
ax3.set_xlabel('Epochs', fontsize = 25)
ax3.set_ylabel('Gradient Norm', fontsize = 25)
ax3.tick_params(axis='both', which='major', labelsize=23)
ax3.tick_params(axis='both', which='minor', labelsize=23)
ax3.legend(fontsize = 25)

#############################################################################################################
#SGD

opti = 'SGD'
lr =  0.08


seed_everything(1234)
model=LeNet()

epoch_list, train_loss_list,train_acc_list, val_loss_list, val_acc_list, batchy_norm, epoch_norm,diff,corr, sc,listttt = TrainVal(
model, train , test, opti ,batch_size, loss_fn, epochs , clipping, lr,  weight_decay,mom, dampening, nest,(0.9,0.999),
eps,tolerance,eta, amsgra,adam_w,
1-adam_w, final_lr,adam_phase=adam_phasee, mix_phase=mix_phasee,
plots = plots, Print = Print, opPrint = opPrint)

accuracy_test, y_pred_list, y_actual = testing(model, test ,32, loss_fn ,plots = True, Print = True)


tot = 0
j = 1
for p in range(5):
    tot +=val_acc_list[-j]
    j +=1

Validation_Acc_result = tot/5

print("Validation_Acc_result = ",Validation_Acc_result)



ax.plot(epoch_list, np.asarray(val_loss_list)*100, label = "ADAM", c =SGD_c)
ax.set_xlabel('Epochs', fontsize = 25)
ax.set_ylabel('Testing Loss', fontsize = 25)
ax.tick_params(axis='both', which='major', labelsize=23)
ax.tick_params(axis='both', which='minor', labelsize=23)
ax.legend(fontsize = 25)


ax2.plot(epoch_list, np.asarray(val_acc_list), label = "ADAM", c =SGD_c)
ax2.set_xlabel('Epochs', fontsize = 25)
ax2.set_ylabel('Testing Accuracy', fontsize = 25)
ax2.tick_params(axis='both', which='major', labelsize=23)
ax2.tick_params(axis='both', which='minor', labelsize=23)
ax2.legend(fontsize = 25)


ax3.plot(epoch_list, epoch_norm, label = "ADAM", c =SGD_c)
ax3.set_xlabel('Epochs', fontsize = 25)
ax3.set_ylabel('Gradient Norm', fontsize = 25)
ax3.tick_params(axis='both', which='major', labelsize=23)
ax3.tick_params(axis='both', which='minor', labelsize=23)
ax3.legend(fontsize = 25)






#############################################################################################################
#SWATS

opti = 'SWATS'

clipping = False # set to false
lr = 0.001
tolerance = 0.0001 # with 1e-3 switches at 7

seed_everything(1234)
model=LeNet()

epoch_list, train_loss_list,train_acc_list, val_loss_list, val_acc_list, batchy_norm, epoch_norm,diff,corr, sc,listttt = TrainVal(
model, train , test, opti ,batch_size, loss_fn, epochs , clipping, lr,  weight_decay,mom, dampening, nest,(0.9,0.999),
eps,tolerance,eta, amsgra,adam_w,
1-adam_w, final_lr,adam_phase=adam_phasee, mix_phase=mix_phasee,
plots = plots, Print = Print, opPrint = opPrint)

accuracy_test, y_pred_list, y_actual = testing(model, test ,32, loss_fn ,plots = True, Print = True)


tot = 0
j = 1
for p in range(5):
    tot +=val_acc_list[-j]
    j +=1

Validation_Acc_result = tot/5

print("Validation_Acc_result = ",Validation_Acc_result)



ax.plot(epoch_list, np.asarray(val_loss_list)*100, label = "SWATS", c =SWATS_c)
ax.set_xlabel('Epochs', fontsize = 25)
ax.set_ylabel('Testing Loss', fontsize = 25)
ax.tick_params(axis='both', which='major', labelsize=23)
ax.tick_params(axis='both', which='minor', labelsize=23)
ax.legend(fontsize = 25)


ax2.plot(epoch_list, np.asarray(val_acc_list), label = "SWATS", c =SWATS_c)
ax2.set_xlabel('Epochs', fontsize = 25)
ax2.set_ylabel('Testing Accuracy', fontsize = 25)
ax2.tick_params(axis='both', which='major', labelsize=23)
ax2.tick_params(axis='both', which='minor', labelsize=23)
ax2.legend(fontsize = 25)


ax3.plot(epoch_list, epoch_norm, label = "SWATS", c =SWATS_c)
ax3.set_xlabel('Epochs', fontsize = 25)
ax3.set_ylabel('Gradient Norm', fontsize = 25)
ax3.tick_params(axis='both', which='major', labelsize=23)
ax3.tick_params(axis='both', which='minor', labelsize=23)
ax3.legend(fontsize = 25)
# Out:
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  4.484595775604248
# The phase is now MIX
# SGD_LR =  2.940678596496582
# The phase is now MIX
# SGD_LR =  7.120392799377441
# The phase is now MIX
# SGD_LR =  1.8110038042068481
# The phase is now MIX
# SGD_LR =  10.45745849609375
# The phase is now MIX
# SGD_LR =  1.0753415822982788
# The phase is now MIX
# SGD_LR =  20.535768508911133
# The phase is now MIX
# SGD_LR =  1.4128330945968628
# The phase is now MIX
# SGD_LR =  2.9869463443756104
# The phase is now MIX
# SGD_LR =  0.13612708449363708
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  2.7489519119262695
# The phase is now MIX
# SGD_LR =  1.7593759298324585
# The phase is now MIX
# SGD_LR =  4.883900165557861
# The phase is now MIX
# SGD_LR =  1.2361069917678833
# The phase is now MIX
# SGD_LR =  7.559246063232422
# The phase is now MIX
# SGD_LR =  0.7543428540229797
# The phase is now MIX
# SGD_LR =  17.101062774658203
# The phase is now MIX
# SGD_LR =  1.170230507850647
# The phase is now MIX
# SGD_LR =  2.1933486461639404
# The phase is now MIX
# SGD_LR =  0.10235864669084549
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  2.060345411300659
# The phase is now MIX
# SGD_LR =  1.2800811529159546
# The phase is now MIX
# SGD_LR =  3.8215739727020264
# The phase is now MIX
# SGD_LR =  0.9633905291557312
# The phase is now MIX
# SGD_LR =  6.1432390213012695
# The phase is now MIX
# SGD_LR =  0.6286754012107849
# The phase is now MIX
# SGD_LR =  15.782620429992676
# The phase is now MIX
# SGD_LR =  1.1068696975708008
# The phase is now MIX
# SGD_LR =  1.8246999979019165
# The phase is now MIX
# SGD_LR =  0.09374388307332993
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  1.6475173234939575
# The phase is now MIX
# SGD_LR =  1.013765811920166
# The phase is now MIX
# SGD_LR =  3.1340291500091553
# The phase is now MIX
# SGD_LR =  0.7840516567230225
# The phase is now MIX
# SGD_LR =  5.190553665161133
# The phase is now MIX
# SGD_LR =  0.5689930319786072
# The phase is now MIX
# SGD_LR =  14.375575065612793
# The phase is now MIX
# SGD_LR =  1.0615086555480957
# The phase is now MIX
# SGD_LR =  1.5412023067474365
# The phase is now MIX
# SGD_LR =  0.08319394290447235
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  1.3944952487945557
# The phase is now MIX
# SGD_LR =  0.847798764705658
# The phase is now MIX
# SGD_LR =  2.704221725463867
# The phase is now MIX
# SGD_LR =  0.6757213473320007
# The phase is now MIX
# SGD_LR =  4.563446998596191
# The phase is now MIX
# SGD_LR =  0.5137968063354492
# The phase is now MIX
# SGD_LR =  13.257305145263672
# The phase is now MIX
# SGD_LR =  0.9934722781181335
# The phase is now MIX
# SGD_LR =  1.358716368675232
# The phase is now MIX
# SGD_LR =  0.07832961529493332
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  1.2134560346603394
# The phase is now MIX
# SGD_LR =  0.7312518954277039
# The phase is now MIX
# SGD_LR =  2.3825697898864746
# The phase is now MIX
# SGD_LR =  0.5987162590026855
# The phase is now MIX
# SGD_LR =  4.070579528808594
# The phase is now MIX
# SGD_LR =  0.45861226320266724
# The phase is now MIX
# SGD_LR =  12.104936599731445
# The phase is now MIX
# SGD_LR =  0.9082426428794861
# The phase is now MIX
# SGD_LR =  1.1944984197616577
# The phase is now MIX
# SGD_LR =  0.07161625474691391
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  1.0728962421417236
# The phase is now MIX
# SGD_LR =  0.6427168846130371
# The phase is now MIX
# SGD_LR =  2.1411237716674805
# The phase is now MIX
# SGD_LR =  0.5377171635627747
# The phase is now MIX
# SGD_LR =  3.735506057739258
# The phase is now MIX
# SGD_LR =  0.43299558758735657
# The phase is now MIX
# SGD_LR =  11.363763809204102
# The phase is now MIX
# SGD_LR =  0.9124954342842102
# The phase is now MIX
# SGD_LR =  1.0769797563552856
# The phase is now MIX
# SGD_LR =  0.07309042662382126
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.9614511728286743
# The phase is now MIX
# SGD_LR =  0.5771010518074036
# The phase is now MIX
# SGD_LR =  1.9424431324005127
# The phase is now MIX
# SGD_LR =  0.4860592186450958
# The phase is now MIX
# SGD_LR =  3.440711736679077
# The phase is now MIX
# SGD_LR =  0.3984936773777008
# The phase is now MIX
# SGD_LR =  10.613574981689453
# The phase is now MIX
# SGD_LR =  0.8902649283409119
# The phase is now MIX
# SGD_LR =  0.973270058631897
# The phase is now MIX
# SGD_LR =  0.06975532323122025
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.8690198063850403
# The phase is now MIX
# SGD_LR =  0.5168156027793884
# The phase is now MIX
# SGD_LR =  1.7687432765960693
# The phase is now MIX
# SGD_LR =  0.44002941250801086
# The phase is now MIX
# SGD_LR =  3.149315357208252
# The phase is now MIX
# SGD_LR =  0.3877204656600952
# The phase is now MIX
# SGD_LR =  9.92836856842041
# The phase is now MIX
# SGD_LR =  0.9247639775276184
# The phase is now MIX
# SGD_LR =  0.8919489979743958
# The phase is now MIX
# SGD_LR =  0.7942349910736084
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.7945771217346191
# The phase is now MIX
# SGD_LR =  0.47069525718688965
# The phase is now MIX
# SGD_LR =  1.6371302604675293
# The phase is now MIX
# SGD_LR =  0.4078492820262909
# The phase is now MIX
# SGD_LR =  2.972109794616699
# The phase is now MIX
# SGD_LR =  0.37823277711868286
# The phase is now MIX
# SGD_LR =  9.394441604614258
# The phase is now MIX
# SGD_LR =  1.0039483308792114
# The phase is now MIX
# SGD_LR =  0.8245822787284851
# The phase is now MIX
# SGD_LR =  0.7257788181304932
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.7317910194396973
# The phase is now MIX
# SGD_LR =  0.4322313666343689
# The phase is now MIX
# SGD_LR =  1.5244910717010498
# The phase is now MIX
# SGD_LR =  0.37993258237838745
# The phase is now MIX
# SGD_LR =  2.8143434524536133
# The phase is now MIX
# SGD_LR =  0.3757304549217224
# The phase is now MIX
# SGD_LR =  8.917173385620117
# The phase is now MIX
# SGD_LR =  1.0268982648849487
# The phase is now MIX
# SGD_LR =  0.768263041973114
# The phase is now MIX
# SGD_LR =  0.6714347004890442
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.6777018904685974
# The phase is now MIX
# SGD_LR =  0.3985556662082672
# The phase is now MIX
# SGD_LR =  1.42598295211792
# The phase is now MIX
# SGD_LR =  0.35290879011154175
# The phase is now MIX
# SGD_LR =  2.673959732055664
# The phase is now MIX
# SGD_LR =  0.35077551007270813
# The phase is now MIX
# SGD_LR =  8.443024635314941
# The phase is now MIX
# SGD_LR =  0.9762123823165894
# The phase is now MIX
# SGD_LR =  0.7148882150650024
# The phase is now MIX
# SGD_LR =  0.6181055903434753
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.6311133503913879
# The phase is now MIX
# SGD_LR =  0.37375280261039734
# The phase is now MIX
# SGD_LR =  1.3396245241165161
# The phase is now MIX
# SGD_LR =  0.3374903202056885
# The phase is now MIX
# SGD_LR =  2.5258023738861084
# The phase is now MIX
# SGD_LR =  0.33177581429481506
# The phase is now MIX
# SGD_LR =  8.010995864868164
# The phase is now MIX
# SGD_LR =  0.9288811683654785
# The phase is now MIX
# SGD_LR =  0.6687353253364563
# The phase is now MIX
# SGD_LR =  0.5726021528244019
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.5945016741752625
# The phase is now MIX
# SGD_LR =  0.3494130074977875
# The phase is now MIX
# SGD_LR =  1.2767293453216553
# The phase is now MIX
# SGD_LR =  0.3173966705799103
# The phase is now MIX
# SGD_LR =  2.416002035140991
# The phase is now MIX
# SGD_LR =  0.31725233793258667
# The phase is now MIX
# SGD_LR =  7.7289228439331055
# The phase is now MIX
# SGD_LR =  0.9793506860733032
# The phase is now MIX
# SGD_LR =  0.634346604347229
# The phase is now MIX
# SGD_LR =  2.412890672683716
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.5647351145744324
# The phase is now MIX
# SGD_LR =  0.3279883861541748
# The phase is now MIX
# SGD_LR =  1.219648003578186
# The phase is now MIX
# SGD_LR =  0.2988073527812958
# The phase is now MIX
# SGD_LR =  2.288611888885498
# The phase is now MIX
# SGD_LR =  0.3011813163757324
# The phase is now MIX
# SGD_LR =  7.362397193908691
# The phase is now MIX
# SGD_LR =  0.9561442732810974
# The phase is now MIX
# SGD_LR =  0.5990229249000549
# The phase is now MIX
# SGD_LR =  2.2549986839294434
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.5319347381591797
# The phase is now MIX
# SGD_LR =  0.31643450260162354
# The phase is now MIX
# SGD_LR =  1.152189016342163
# The phase is now MIX
# SGD_LR =  0.2833830416202545
# The phase is now MIX
# SGD_LR =  2.169865608215332
# The phase is now MIX
# SGD_LR =  0.2886990010738373
# The phase is now MIX
# SGD_LR =  7.029326438903809
# The phase is now MIX
# SGD_LR =  0.9326883554458618
# The phase is now MIX
# SGD_LR =  0.5676780343055725
# The phase is now MIX
# SGD_LR =  2.116190195083618
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.5285659432411194
# The phase is now MIX
# SGD_LR =  0.2993611991405487
# The phase is now MIX
# SGD_LR =  1.158187985420227
# The phase is now MIX
# SGD_LR =  0.2687584459781647
# The phase is now MIX
# SGD_LR =  2.0985019207000732
# The phase is now MIX
# SGD_LR =  0.27587181329727173
# The phase is now MIX
# SGD_LR =  6.768591403961182
# The phase is now MIX
# SGD_LR =  0.9037705063819885
# The phase is now MIX
# SGD_LR =  0.5406121015548706
# The phase is now MIX
# SGD_LR =  1.99355149269104
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.5063470602035522
# The phase is now MIX
# SGD_LR =  0.2839599847793579
# The phase is now MIX
# SGD_LR =  1.1156706809997559
# The phase is now MIX
# SGD_LR =  0.2553386986255646
# The phase is now MIX
# SGD_LR =  2.017566680908203
# The phase is now MIX
# SGD_LR =  0.2639661431312561
# The phase is now MIX
# SGD_LR =  6.522749900817871
# The phase is now MIX
# SGD_LR =  0.8725690841674805
# The phase is now MIX
# SGD_LR =  0.5158783197402954
# The phase is now MIX
# SGD_LR =  1.8838785886764526
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.4922957420349121
# The phase is now MIX
# SGD_LR =  0.2715798616409302
# The phase is now MIX
# SGD_LR =  1.0940889120101929
# The phase is now MIX
# SGD_LR =  0.24489979445934296
# The phase is now MIX
# SGD_LR =  1.9671598672866821
# The phase is now MIX
# SGD_LR =  0.2581555247306824
# The phase is now MIX
# SGD_LR =  6.2806315422058105
# The phase is now MIX
# SGD_LR =  0.8509901165962219
# The phase is now MIX
# SGD_LR =  0.4929071068763733
# The phase is now MIX
# SGD_LR =  1.786840796470642
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.4743521213531494
# The phase is now MIX
# SGD_LR =  0.26090720295906067
# The phase is now MIX
# SGD_LR =  1.0701863765716553
# The phase is now MIX
# SGD_LR =  0.24051907658576965
# The phase is now MIX
# SGD_LR =  1.9206265211105347
# The phase is now MIX
# SGD_LR =  0.2626760005950928
# The phase is now MIX
# SGD_LR =  6.106743812561035
# The phase is now MIX
# SGD_LR =  0.8460128307342529
# The phase is now MIX
# SGD_LR =  0.4735608398914337
# The phase is now MIX
# SGD_LR =  1.6997288465499878
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.45569583773612976
# The phase is now MIX
# SGD_LR =  0.25064513087272644
# The phase is now MIX
# SGD_LR =  1.0374552011489868
# The phase is now MIX
# SGD_LR =  0.30670303106307983
# The phase is now MIX
# SGD_LR =  1.8524748086929321
# The phase is now MIX
# SGD_LR =  0.2443704456090927
# The phase is now MIX
# SGD_LR =  5.979647159576416
# The phase is now MIX
# SGD_LR =  0.7691770792007446
# The phase is now MIX
# SGD_LR =  0.45725810527801514
# The phase is now MIX
# SGD_LR =  1.6140670776367188
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.4391482174396515
# The phase is now MIX
# SGD_LR =  0.24088585376739502
# The phase is now MIX
# SGD_LR =  1.0048956871032715
# The phase is now MIX
# SGD_LR =  0.29382893443107605
# The phase is now MIX
# SGD_LR =  1.8189818859100342
# The phase is now MIX
# SGD_LR =  0.23647621273994446
# The phase is now MIX
# SGD_LR =  5.842683792114258
# The phase is now MIX
# SGD_LR =  0.7514639496803284
# The phase is now MIX
# SGD_LR =  0.44175985455513
# The phase is now MIX
# SGD_LR =  1.5413366556167603
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.42466673254966736
# The phase is now MIX
# SGD_LR =  0.23148740828037262
# The phase is now MIX
# SGD_LR =  0.9739901423454285
# The phase is now MIX
# SGD_LR =  0.28198277950286865
# The phase is now MIX
# SGD_LR =  1.7853848934173584
# The phase is now MIX
# SGD_LR =  0.22797496616840363
# The phase is now MIX
# SGD_LR =  5.719977378845215
# The phase is now MIX
# SGD_LR =  0.7296566963195801
# The phase is now MIX
# SGD_LR =  0.42738738656044006
# The phase is now MIX
# SGD_LR =  1.4746416807174683
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.41097164154052734
# The phase is now MIX
# SGD_LR =  0.22491303086280823
# The phase is now MIX
# SGD_LR =  0.9541144967079163
# The phase is now MIX
# SGD_LR =  0.27732282876968384
# The phase is now MIX
# SGD_LR =  1.7499653100967407
# The phase is now MIX
# SGD_LR =  0.22312510013580322
# The phase is now MIX
# SGD_LR =  5.602947235107422
# The phase is now MIX
# SGD_LR =  0.7161292433738708
# The phase is now MIX
# SGD_LR =  0.4157901406288147
# The phase is now MIX
# SGD_LR =  1.414018988609314
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.3970375061035156
# The phase is now MIX
# SGD_LR =  0.21763601899147034
# The phase is now MIX
# SGD_LR =  0.9302665591239929
# The phase is now MIX
# SGD_LR =  0.26935121417045593
# The phase is now MIX
# SGD_LR =  1.711716651916504
# The phase is now MIX
# SGD_LR =  0.2182447463274002
# The phase is now MIX
# SGD_LR =  5.500356197357178
# The phase is now MIX
# SGD_LR =  0.7057306170463562
# The phase is now MIX
# SGD_LR =  0.40335655212402344
# The phase is now MIX
# SGD_LR =  1.358201026916504
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.38389328122138977
# The phase is now MIX
# SGD_LR =  0.21094708144664764
# The phase is now MIX
# SGD_LR =  0.9042558073997498
# The phase is now MIX
# SGD_LR =  0.26321423053741455
# The phase is now MIX
# SGD_LR =  1.6746608018875122
# The phase is now MIX
# SGD_LR =  0.2163620889186859
# The phase is now MIX
# SGD_LR =  5.457925796508789
# The phase is now MIX
# SGD_LR =  0.7123761773109436
# The phase is now MIX
# SGD_LR =  0.3972379267215729
# The phase is now MIX
# SGD_LR =  1.3102542161941528
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.3720986247062683
# The phase is now MIX
# SGD_LR =  0.20415741205215454
# The phase is now MIX
# SGD_LR =  0.8826953768730164
# The phase is now MIX
# SGD_LR =  0.25647103786468506
# The phase is now MIX
# SGD_LR =  1.642911672592163
# The phase is now MIX
# SGD_LR =  0.21704377233982086
# The phase is now MIX
# SGD_LR =  5.361124515533447
# The phase is now MIX
# SGD_LR =  0.7119555473327637
# The phase is now MIX
# SGD_LR =  0.3868439495563507
# The phase is now MIX
# SGD_LR =  1.2654187679290771
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.36158981919288635
# The phase is now MIX
# SGD_LR =  0.19730137288570404
# The phase is now MIX
# SGD_LR =  0.858083188533783
# The phase is now MIX
# SGD_LR =  0.24835912883281708
# The phase is now MIX
# SGD_LR =  1.604775309562683
# The phase is now MIX
# SGD_LR =  0.2156786471605301
# The phase is now MIX
# SGD_LR =  5.259910583496094
# The phase is now MIX
# SGD_LR =  0.7078645825386047
# The phase is now MIX
# SGD_LR =  0.37703704833984375
# The phase is now MIX
# SGD_LR =  1.2229938507080078
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.35123705863952637
# The phase is now MIX
# SGD_LR =  0.19141335785388947
# The phase is now MIX
# SGD_LR =  0.838802695274353
# The phase is now MIX
# SGD_LR =  0.26792892813682556
# The phase is now MIX
# SGD_LR =  1.5772616863250732
# The phase is now MIX
# SGD_LR =  0.2152763158082962
# The phase is now MIX
# SGD_LR =  5.187501907348633
# The phase is now MIX
# SGD_LR =  0.7058439254760742
# The phase is now MIX
# SGD_LR =  0.36818453669548035
# The phase is now MIX
# SGD_LR =  1.1832408905029297
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.3407990634441376
# The phase is now MIX
# SGD_LR =  0.1854025274515152
# The phase is now MIX
# SGD_LR =  0.8173873424530029
# The phase is now MIX
# SGD_LR =  0.25968486070632935
# The phase is now MIX
# SGD_LR =  1.5637848377227783
# The phase is now MIX
# SGD_LR =  0.20979399979114532
# The phase is now MIX
# SGD_LR =  5.11643123626709
# The phase is now MIX
# SGD_LR =  0.6948632001876831
# The phase is now MIX
# SGD_LR =  0.3598294258117676
# The phase is now MIX
# SGD_LR =  1.1448427438735962
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.3321900963783264
# The phase is now MIX
# SGD_LR =  0.18096823990345
# The phase is now MIX
# SGD_LR =  0.8044300675392151
# The phase is now MIX
# SGD_LR =  0.27743905782699585
# The phase is now MIX
# SGD_LR =  1.541894555091858
# The phase is now MIX
# SGD_LR =  0.20736375451087952
# The phase is now MIX
# SGD_LR =  5.057903289794922
# The phase is now MIX
# SGD_LR =  0.6909586787223816
# The phase is now MIX
# SGD_LR =  0.3522115647792816
# The phase is now MIX
# SGD_LR =  1.109147071838379
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.3232070803642273
# The phase is now MIX
# SGD_LR =  0.18566150963306427
# The phase is now MIX
# SGD_LR =  0.7850373983383179
# The phase is now MIX
# SGD_LR =  0.27248910069465637
# The phase is now MIX
# SGD_LR =  1.5059219598770142
# The phase is now MIX
# SGD_LR =  0.2041693776845932
# The phase is now MIX
# SGD_LR =  4.98124361038208
# The phase is now MIX
# SGD_LR =  0.6835983991622925
# The phase is now MIX
# SGD_LR =  0.3446411192417145
# The phase is now MIX
# SGD_LR =  1.0751254558563232
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.3141978979110718
# The phase is now MIX
# SGD_LR =  0.18011616170406342
# The phase is now MIX
# SGD_LR =  0.7636142373085022
# The phase is now MIX
# SGD_LR =  0.2644086480140686
# The phase is now MIX
# SGD_LR =  1.4694589376449585
# The phase is now MIX
# SGD_LR =  0.19899672269821167
# The phase is now MIX
# SGD_LR =  4.895899772644043
# The phase is now MIX
# SGD_LR =  0.6719231605529785
# The phase is now MIX
# SGD_LR =  0.33707958459854126
# The phase is now MIX
# SGD_LR =  1.0428842306137085
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.3072299659252167
# The phase is now MIX
# SGD_LR =  0.16760550439357758
# The phase is now MIX
# SGD_LR =  0.7528699040412903
# The phase is now MIX
# SGD_LR =  0.26214438676834106
# The phase is now MIX
# SGD_LR =  1.4392716884613037
# The phase is now MIX
# SGD_LR =  0.19604818522930145
# The phase is now MIX
# SGD_LR =  4.82687520980835
# The phase is now MIX
# SGD_LR =  0.6655362844467163
# The phase is now MIX
# SGD_LR =  0.3305746018886566
# The phase is now MIX
# SGD_LR =  1.0128173828125
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.2992263734340668
# The phase is now MIX
# SGD_LR =  0.16396567225456238
# The phase is now MIX
# SGD_LR =  0.7342314720153809
# The phase is now MIX
# SGD_LR =  0.2534158527851105
# The phase is now MIX
# SGD_LR =  1.4062492847442627
# The phase is now MIX
# SGD_LR =  0.183279350399971
# The phase is now MIX
# SGD_LR =  4.768121719360352
# The phase is now MIX
# SGD_LR =  0.6973443627357483
# The phase is now MIX
# SGD_LR =  0.3243848383426666
# The phase is now MIX
# SGD_LR =  0.992172122001648
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.29203271865844727
# The phase is now MIX
# SGD_LR =  0.15948133170604706
# The phase is now MIX
# SGD_LR =  0.717394232749939
# The phase is now MIX
# SGD_LR =  0.24653500318527222
# The phase is now MIX
# SGD_LR =  1.3784866333007812
# The phase is now MIX
# SGD_LR =  0.17975880205631256
# The phase is now MIX
# SGD_LR =  4.704293251037598
# The phase is now MIX
# SGD_LR =  0.6935650706291199
# The phase is now MIX
# SGD_LR =  0.3181455731391907
# The phase is now MIX
# SGD_LR =  0.9658436179161072
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.2866557538509369
# The phase is now MIX
# SGD_LR =  0.1569865643978119
# The phase is now MIX
# SGD_LR =  0.7131441831588745
# The phase is now MIX
# SGD_LR =  0.2450104057788849
# The phase is now MIX
# SGD_LR =  1.3692089319229126
# The phase is now MIX
# SGD_LR =  0.17756213247776031
# The phase is now MIX
# SGD_LR =  4.641634464263916
# The phase is now MIX
# SGD_LR =  0.6878734230995178
# The phase is now MIX
# SGD_LR =  0.3121020793914795
# The phase is now MIX
# SGD_LR =  0.9403562545776367
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.2815985381603241
# The phase is now MIX
# SGD_LR =  0.15349005162715912
# The phase is now MIX
# SGD_LR =  0.7065978646278381
# The phase is now MIX
# SGD_LR =  0.2398354411125183
# The phase is now MIX
# SGD_LR =  1.3521385192871094
# The phase is now MIX
# SGD_LR =  0.17541196942329407
# The phase is now MIX
# SGD_LR =  4.576272487640381
# The phase is now MIX
# SGD_LR =  0.6815924048423767
# The phase is now MIX
# SGD_LR =  0.3065566420555115
# The phase is now MIX
# SGD_LR =  0.9163227081298828
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.2758152484893799
# The phase is now MIX
# SGD_LR =  0.14997726678848267
# The phase is now MIX
# SGD_LR =  0.6945024132728577
# The phase is now MIX
# SGD_LR =  0.2344362884759903
# The phase is now MIX
# SGD_LR =  1.3318064212799072
# The phase is now MIX
# SGD_LR =  0.17334643006324768
# The phase is now MIX
# SGD_LR =  4.526949882507324
# The phase is now MIX
# SGD_LR =  0.6812999844551086
# The phase is now MIX
# SGD_LR =  0.30120766162872314
# The phase is now MIX
# SGD_LR =  0.8944586515426636
# ADAM | Current epoch =  1
# The phase is now MIX
# SGD_LR =  0.2693467438220978
# The phase is now MIX
# SGD_LR =  0.14637383818626404
# The phase is now MIX
# SGD_LR =  0.6781694293022156
# The phase is now MIX
# SGD_LR =  0.22904954850673676
# The phase is now MIX
# SGD_LR =  1.3002430200576782
# The phase is now MIX
# SGD_LR =  0.1658594161272049
# The phase is now MIX
# SGD_LR =  4.4242095947265625
# The phase is now MIX
# SGD_LR =  0.6677042245864868
# The phase is now MIX
# SGD_LR =  0.29407835006713867
# The phase is now MIX
# SGD_LR =  0.8722986578941345
# Epoch: 1 	Train Loss: 0.0020	 Acc: 25.53%
# Epoch: 1 	Val Loss: 0.0000	 Acc: 34.45%
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# ADAM | Current epoch =  2
# Epoch: 2 	Train Loss: 0.0017	 Acc: 36.82%
# Epoch: 2 	Val Loss: 0.0000	 Acc: 40.27%
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
#
# Mix batch count =  0
#
# MIX | Current epoch =  3
# MIX | SGD Weight =  0.0
# MIX | Adam Weight =  1.0
# Epoch: 3 	Train Loss: 0.0016	 Acc: 41.60%
# Epoch: 3 	Val Loss: 0.0000	 Acc: 43.95%
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
#
# Mix batch count =  1
#
# MIX | Current epoch =  4
# MIX | SGD Weight =  0.25
# MIX | Adam Weight =  0.75
# Epoch: 4 	Train Loss: 0.2645	 Acc: 10.88%
# Epoch: 4 	Val Loss: 0.0000	 Acc: 10.37%
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
#
# Mix batch count =  2
#
# MIX | Current epoch =  5
# MIX | SGD Weight =  0.5
# MIX | Adam Weight =  0.5
# Epoch: 5 	Train Loss: 0.0023	 Acc: 9.97%
# Epoch: 5 	Val Loss: 0.0000	 Acc: 9.34%
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
#
# Mix batch count =  3
#
# MIX | Current epoch =  6
# MIX | SGD Weight =  0.75
# MIX | Adam Weight =  0.25
# Epoch: 6 	Train Loss: 0.0023	 Acc: 10.09%
# Epoch: 6 	Val Loss: 0.0000	 Acc: 9.97%
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
#
# Mix batch count =  4
#
# MIX | Current epoch =  7
# MIX | SGD Weight =  1.0
# MIX | Adam Weight =  0.0
# Epoch: 7 	Train Loss: 0.0023	 Acc: 10.14%
# Epoch: 7 	Val Loss: 0.0000	 Acc: 9.80%
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# SGD | Current epoch =  8
# Epoch: 8 	Train Loss: 0.0023	 Acc: 10.06%
# Epoch: 8 	Val Loss: 0.0000	 Acc: 9.86%
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# SGD | Current epoch =  9
# Epoch: 9 	Train Loss: 0.0023	 Acc: 9.87%
# Epoch: 9 	Val Loss: 0.0000	 Acc: 9.93%
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# SGD | Current epoch =  10
# Epoch: 10 	Train Loss: 0.0023	 Acc: 9.85%
# Epoch: 10 	Val Loss: 0.0000	 Acc: 10.00%
# test Accuracy =  10.0
# test loss =  0.07214353244304657
# Validation_Acc_result =  9.912
# Epoch: 1 	Train Loss: 0.0021	 Acc: 24.11%
# Epoch: 1 	Val Loss: 0.0000	 Acc: 31.74%
# Epoch: 2 	Train Loss: 0.0018	 Acc: 34.59%
# Epoch: 2 	Val Loss: 0.0000	 Acc: 37.82%
# Epoch: 3 	Train Loss: 0.0017	 Acc: 39.74%
# Epoch: 3 	Val Loss: 0.0000	 Acc: 41.72%
# Epoch: 4 	Train Loss: 0.0016	 Acc: 42.19%
# Epoch: 4 	Val Loss: 0.0000	 Acc: 44.73%
# Epoch: 5 	Train Loss: 0.0015	 Acc: 44.41%
# Epoch: 5 	Val Loss: 0.0000	 Acc: 44.43%
# Epoch: 6 	Train Loss: 0.0015	 Acc: 45.93%
# Epoch: 6 	Val Loss: 0.0000	 Acc: 47.36%
# Epoch: 7 	Train Loss: 0.0015	 Acc: 47.25%
# Epoch: 7 	Val Loss: 0.0000	 Acc: 47.36%
# Epoch: 8 	Train Loss: 0.0014	 Acc: 47.98%
# Epoch: 8 	Val Loss: 0.0000	 Acc: 49.88%
# Epoch: 9 	Train Loss: 0.0014	 Acc: 49.23%
# Epoch: 9 	Val Loss: 0.0000	 Acc: 50.74%
# Epoch: 10 	Train Loss: 0.0014	 Acc: 50.51%
# Epoch: 10 	Val Loss: 0.0000	 Acc: 51.30%
# test Accuracy =  53.96
# test loss =  0.03976478669643402
# Validation_Acc_result =  49.327999999999996
# Epoch: 1 	Train Loss: 0.0022	 Acc: 17.30%
# Epoch: 1 	Val Loss: 0.0000	 Acc: 26.10%
# Epoch: 2 	Train Loss: 0.0019	 Acc: 28.18%
# Epoch: 2 	Val Loss: 0.0000	 Acc: 30.85%
# Epoch: 3 	Train Loss: 0.0017	 Acc: 36.91%
# Epoch: 3 	Val Loss: 0.0000	 Acc: 42.67%
# Epoch: 4 	Train Loss: 0.0015	 Acc: 44.46%
# Epoch: 4 	Val Loss: 0.0000	 Acc: 48.19%
# Epoch: 5 	Train Loss: 0.0014	 Acc: 48.91%
# Epoch: 5 	Val Loss: 0.0000	 Acc: 48.01%
# Epoch: 6 	Train Loss: 0.0014	 Acc: 50.75%
# Epoch: 6 	Val Loss: 0.0000	 Acc: 52.76%
# Epoch: 7 	Train Loss: 0.0013	 Acc: 52.98%
# Epoch: 7 	Val Loss: 0.0000	 Acc: 56.01%
# Epoch: 8 	Train Loss: 0.0012	 Acc: 55.46%
# Epoch: 8 	Val Loss: 0.0000	 Acc: 55.50%
# Epoch: 9 	Train Loss: 0.0012	 Acc: 57.56%
# Epoch: 9 	Val Loss: 0.0000	 Acc: 59.86%
# Epoch: 10 	Train Loss: 0.0012	 Acc: 58.39%
# Epoch: 10 	Val Loss: 0.0000	 Acc: 60.45%
# test Accuracy =  64.38
# test loss =  0.031005461639165878
# Validation_Acc_result =  56.916
# Epoch: 1 	Train Loss: 0.0020	 Acc: 25.53%
# Epoch: 1 	Val Loss: 0.0000	 Acc: 34.45%
# Epoch: 2 	Train Loss: 0.0017	 Acc: 36.82%
# Epoch: 2 	Val Loss: 0.0000	 Acc: 40.27%
# Epoch: 3 	Train Loss: 0.0016	 Acc: 41.60%
# Epoch: 3 	Val Loss: 0.0000	 Acc: 43.95%
# Epoch: 4 	Train Loss: 0.0016	 Acc: 44.02%
# Epoch: 4 	Val Loss: 0.0000	 Acc: 46.32%
# Epoch: 5 	Train Loss: 0.0015	 Acc: 46.20%
# Epoch: 5 	Val Loss: 0.0000	 Acc: 44.75%
# Epoch: 6 	Train Loss: 0.0015	 Acc: 47.52%
# Epoch: 6 	Val Loss: 0.0000	 Acc: 49.12%
# Epoch: 7 	Train Loss: 0.0014	 Acc: 49.03%
# Epoch: 7 	Val Loss: 0.0000	 Acc: 49.87%
# Epoch: 8 	Train Loss: 0.0014	 Acc: 50.28%
# Epoch: 8 	Val Loss: 0.0000	 Acc: 51.50%
# corrected lr  =  0.29490476846694946
# SGD OG lr 0.29490476846694946
# Epoch: 9 	Train Loss: nan	 Acc: 29.77%
# Epoch: 9 	Val Loss: nan	 Acc: 9.97%
# Epoch: 10 	Train Loss: nan	 Acc: 10.01%
# Epoch: 10 	Val Loss: nan	 Acc: 9.97%
# test Accuracy =  10.0
# test loss =  nan
# Validation_Acc_result =  34.086

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot()

x = []
for i in range(epochs):
    x.append(i+1)


fig = plt.figure()
param2 = []
for i in range(epochs):
    param2.append(corr[i][2])
    
ax.plot(x,param2, label = '$ \Lambda_k$', c = 'blue')


param22 = []
for i in range(epochs):
    param22.append(sc[i][2])
ax.plot(x,param22, label = '$ \gamma_k$', c ='black')
ax.set_xlabel('Epochs')
ax.set_ylabel('Scaling estimates')
ax.legend()

a = np.linspace(0,0.06,7)
ax.set_yticklabels(a)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:26: UserWarning: FixedFormatter should only be used together with FixedLocator
# [Text(0, 0.0, '0.0'),
#  Text(0, 1.0, '0.01'),
#  Text(0, 2.0, '0.02'),
#  Text(0, 3.0, '0.03'),
#  Text(0, 4.0, '0.04'),
#  Text(0, 5.0, '0.05'),
#  Text(0, 6.0, '0.06'),
#  Text(0, 7.0, ''),
#  Text(0, 8.0, '')]

# %%
#print(diff,corr,sc)

fig = plt.figure(figsize=(14,10))
ax = fig.add_subplot()

x = []
for i in range(epochs):
    x.append(i+1)


fig = plt.figure()
param2 = []
for i in range(epochs):
    param2.append(corr[i][2])
    
ax.plot(x,param2, label = '$ \Lambda_k$', c = 'blue')


param22 = []
for i in range(epochs):
    param22.append(sc[i][2])
ax.plot(x,param22, label = '$ \gamma_k$', c ='black')
ax.set_xlabel('Epochs',fontsize = 25)
ax.set_ylabel('Learning rate estimates',fontsize = 25)
ax.legend(fontsize = 25)
ax.tick_params(axis='both', which='major', labelsize=23)
ax.tick_params(axis='both', which='minor', labelsize=23)




fig = plt.figure(figsize=(14,10))
ax = fig.add_subplot()

param6 = []
for i in range(epochs):
    param6.append(corr[i][6])
    
ax.plot(x,param6, label = '$ \Lambda_k$', c = 'blue')


param66 = []
for i in range(epochs):
    param66.append(sc[i][6])
ax.plot(x,param66, label = '$ \gamma_k$', c ='black')
ax.set_xlabel('Epochs',fontsize = 25)
ax.set_ylabel('Learning rate estimates',fontsize = 25)

ax.tick_params(axis='both', which='major', labelsize=23)
ax.tick_params(axis='both', which='minor', labelsize=23)
ax.legend(fontsize = 25)

a = np.linspace(0,0.06,10)
ax.set_yticklabels(np.round(a,3))
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:54: UserWarning: FixedFormatter should only be used together with FixedLocator
# [Text(0, 2.0, '0.0'),
#  Text(0, 4.0, '0.007'),
#  Text(0, 6.0, '0.013'),
#  Text(0, 8.0, '0.02'),
#  Text(0, 10.0, '0.027'),
#  Text(0, 12.0, '0.033'),
#  Text(0, 14.0, '0.04'),
#  Text(0, 16.0, '0.047'),
#  Text(0, 18.0, '0.053'),
#  Text(0, 20.0, '0.06'),
#  Text(0, 22.0, '')]

# %% [markdown]
# ADAM
